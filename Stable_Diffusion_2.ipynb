# %%
! pip install transformers diffusers torch accelerate -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 4.6 MB/s eta 0:00:00

# %%
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler
import torch
import transformers

model_id = "stabilityai/stable-diffusion-2"
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "a photo of an astronaut riding a horse on mars"
image = pipe(prompt).images[0]
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
print(image)
# Out:
# <PIL.Image.Image image mode=RGB size=768x768 at 0x7A6E859B0F70>

# %%
out = pipe("Generate an image of a human riding a bicycle while holding a water bottle.")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
out.images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=768x768>

# %%
out = pipe("Create an image of an alien standing next to a water cooler, pouring water into a cup from the cooler.")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
out.images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=768x768>
